# %%
import data_preparation as dp

dp.METABRIC_preprocess()

# %%
import pandas as pd
merged_data = pd.read_csv('../data/METABRIC/merged_data.csv')

merged_data_save = merged_data.copy()

merged_data_g = merged_data.groupby('PID')

merged_data_g = merged_data_g.mean()
# Out:
# /var/folders/k2/mmnsl0v1443297g72q3p30cw0000gn/T/ipykernel_23464/3498005178.py:2: DtypeWarning: Columns (67) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_data = pd.read_csv('../data/METABRIC/merged_data.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the box plot for Overall Survival (Months) across different clinical types
plt.figure(figsize=(12, 6))
ax = sns.boxplot(x='clinical_type', y='OSmonth', data=merged_data)
plt.title('Distribution of Overall Survival (Months) by Clinical Type')
plt.xlabel('Clinical Type')
plt.ylabel('Overall Survival (Months)')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the box plot for Overall Survival (Months) across different clinical types
plt.figure(figsize=(12, 6))
ax = sns.boxplot(x='clinical_type', y='age', data=merged_data)
plt.title('Distribution of Overall Survival (Months) by Clinical Type')
plt.xlabel('Clinical Type')
plt.ylabel('Age')
plt.xticks(rotation=45)
plt.show()

# %%
# Plotting the box plot for Overall Survival (Months) across different clinical types
plt.figure(figsize=(12, 6))
ax = sns.boxplot(x='age', y='OSmonth', data=merged_data)
plt.title('Distribution of Overall Survival (Months) by Clinical Type')
plt.xlabel('Age')
plt.ylabel('Overall Survival (Months)')
plt.xticks(rotation=45)
plt.show()

# %%
import scipy.stats as stats

# Assuming 'age' and 'OSmonth' are columns in your DataFrame 'merged_data'
x = merged_data['age']
y = merged_data['OSmonth']

# Calculate the Pearson correlation coefficient and the p-value
correlation_coefficient, p_value = stats.pearsonr(x, y)

# Print the results
print("Pearson correlation coefficient:", correlation_coefficient)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 8
#       5 y = merged_data['OSmonth']
#       7 # Calculate the Pearson correlation coefficient and the p-value
# ----> 8 correlation_coefficient, p_value = stats.pearsonr(x, y)
#      10 # Print the results
#      11 print("Pearson correlation coefficient:", correlation_coefficient)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/COPred/lib/python3.9/site-packages/scipy/stats/_stats_py.py:4452, in pearsonr(x, y, alternative)
#    4448 # Unlike np.linalg.norm or the expression sqrt((xm*xm).sum()),
#    4449 # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    4450 # [-5e210, 5e210, 3e200, -3e200]
#    4451 normxm = linalg.norm(xm)
# -> 4452 normym = linalg.norm(ym)
#    4454 threshold = 1e-13
#    4455 if normxm < threshold*abs(xmean) or normym < threshold*abs(ymean):
# ...

# %%
# Checking for nan for age and osmonth in merged_data

# Path: bin/testing5.ipynb

# %%
import visualizer

visualizer.visualize_clinical_data('bin/testing4.ipynb')
# Out:
# Clinical data columns:  Index(['Study ID', 'Patient ID', 'Sample ID', 'Age at Diagnosis',
#        'Type of Breast Surgery', 'Cancer Type', 'Cancer Type Detailed',
#        'Cellularity', 'Chemotherapy', 'Pam50 + Claudin-low subtype', 'Cohort',
#        'ER status measured by IHC', 'ER Status', 'Neoplasm Histologic Grade',
#        'HER2 status measured by SNP6', 'HER2 Status',
#        'Tumor Other Histologic Subtype', 'Hormone Therapy',
#        'Inferred Menopausal State', 'Integrative Cluster',
#        'Primary Tumor Laterality', 'Lymph nodes examined positive',
#        'Mutation Count', 'Nottingham prognostic index', 'Oncotree Code',
#        'Overall Survival (Months)', 'Overall Survival Status', 'PR Status',
#        'Radio Therapy', 'Relapse Free Status (Months)', 'Relapse Free Status',
#        'Number of Samples Per Patient', 'Sample Type', 'Sex',
#        '3-Gene classifier subtype', 'TMB (nonsynonymous)', 'Tumor Size',
#        'Tumor Stage', 'Patient's Vital Status'],
# ...

# %%
import pandas as pd
c_data  = pd.read_csv("../data/METABRIC/brca_metabric_clinical_data.tsv", sep="\t", index_col=False)
    

# Print columns
print("Clinical data columns: ", c_data.columns)

# Clean the column names by removing leading and trailing whitespaces
c_data.columns = c_data.columns.str.strip()

# Count unique Patient IDs in clinical data
print("Unique Patient IDs in clinical data: ", len(c_data["Patient ID"].unique()))
# Out:
# Clinical data columns:  Index(['Study ID', 'Patient ID', 'Sample ID', 'Age at Diagnosis',
#        'Type of Breast Surgery', 'Cancer Type', 'Cancer Type Detailed',
#        'Cellularity', 'Chemotherapy', 'Pam50 + Claudin-low subtype', 'Cohort',
#        'ER status measured by IHC', 'ER Status', 'Neoplasm Histologic Grade',
#        'HER2 status measured by SNP6', 'HER2 Status',
#        'Tumor Other Histologic Subtype', 'Hormone Therapy',
#        'Inferred Menopausal State', 'Integrative Cluster',
#        'Primary Tumor Laterality', 'Lymph nodes examined positive',
#        'Mutation Count', 'Nottingham prognostic index', 'Oncotree Code',
#        'Overall Survival (Months)', 'Overall Survival Status', 'PR Status',
#        'Radio Therapy', 'Relapse Free Status (Months)', 'Relapse Free Status',
#        'Number of Samples Per Patient', 'Sample Type', 'Sex',
#        '3-Gene classifier subtype', 'TMB (nonsynonymous)', 'Tumor Size',
#        'Tumor Stage', 'Patient's Vital Status'],
# ...

# %%
print("Clinical data columns: ", c_data.columns)
# Out:
# Clinical data columns:  Index(['Study ID', 'Patient ID', 'Sample ID', 'Age at Diagnosis',
#        'Type of Breast Surgery', 'Cancer Type', 'Cancer Type Detailed',
#        'Cellularity', 'Chemotherapy', 'Pam50 + Claudin-low subtype', 'Cohort',
#        'ER status measured by IHC', 'ER Status', 'Neoplasm Histologic Grade',
#        'HER2 status measured by SNP6', 'HER2 Status',
#        'Tumor Other Histologic Subtype', 'Hormone Therapy',
#        'Inferred Menopausal State', 'Integrative Cluster',
#        'Primary Tumor Laterality', 'Lymph nodes examined positive',
#        'Mutation Count', 'Nottingham prognostic index', 'Oncotree Code',
#        'Overall Survival (Months)', 'Overall Survival Status', 'PR Status',
#        'Radio Therapy', 'Relapse Free Status (Months)', 'Relapse Free Status',
#        'Number of Samples Per Patient', 'Sample Type', 'Sex',
#        '3-Gene classifier subtype', 'TMB (nonsynonymous)', 'Tumor Size',
#        'Tumor Stage', 'Patient's Vital Status'],
# ...

# %% [markdown]
# merged_metabric = pd.read_csv('../data/METABRIC/merged_data.csv')

# %%
import pandas as pd
merged_metabric = pd.read_csv('../data/METABRIC/merged_data.csv')
# Out:
# /var/folders/k2/mmnsl0v1443297g72q3p30cw0000gn/T/ipykernel_56970/1453436737.py:2: DtypeWarning: Columns (67) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_metabric = pd.read_csv('../data/METABRIC/merged_data.csv')
